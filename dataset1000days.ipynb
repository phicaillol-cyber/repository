# %% [markdown]
# <a href="https://colab.research.google.com/github/phicaillol-cyber/repository/blob/main/dataset1000days.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

# Définir la période de 1000 jours
end_date = datetime.now()
start_date = end_date - timedelta(days=1000)

# Liste des tickers du CAC 40 (exemple : 'OR.PA' pour L'Oréal)
cac40_tickers = cac40_tickers = [
    "AI.PA",   # Air Liquide
    "AIR.PA",  # Airbus
    "ALO.PA",  # Alstom
    "CS.PA",   # AXA
    "BNP.PA",  # BNP Paribas
    "EN.PA",   # Bouygues
    "CAP.PA",  # Capgemini
    "CA.PA",   # Carrefour
    "ACA.PA",  # Crédit Agricole
    "BN.PA",   # Danone
    "DSY.PA",  # Dassault Systèmes
    "EDEN.PA", # Edenred
    "ENGI.PA", # Engie
    "EL.PA",   # EssilorLuxottica
    "ERF.PA",  # Eurofins Scientific
    "RMS.PA",  # Hermès
    "KER.PA",  # Kering
    "LR.PA",   # Legrand
    "OR.PA",   # L'Oréal
    "MC.PA",   # LVMH
    "ML.PA",   # Michelin
    "ORA.PA",  # Orange
    "RI.PA",   # Pernod Ricard
    "PUB.PA",  # Publicis
    "RNO.PA",  # Renault
    "SAF.PA",  # Safran
    "SGO.PA",  # Saint-Gobain
    "SAN.PA",  # Sanofi
    "SU.PA",   # Schneider Electric
    "GLE.PA",  # Société Générale
    "TEP.PA",  # Teleperformance
    "HO.PA",   # Thales
    "TTE.PA",  # TotalEnergies
    "URW.PA",  # Unibail-Rodamco-Westfield
    "VIE.PA",  # Veolia
    "DG.PA",   # Vinci
    "VIV.PA",  # Vivendi
    "WLN.PA"   # Worldline
]

# Liste des tickers du NASDAQ (exemple : 'AAPL' pour Apple)
nasdaq_tickers = nasdaq_top_40 = [
    "AAPL",  # Apple
    "MSFT",  # Microsoft
    "GOOGL", # Alphabet (Google)
    "AMZN",  # Amazon
    "META",  # Meta (Facebook)
    "NVDA",  # NVIDIA
    "TSLA",  # Tesla
    "AVGO",  # Broadcom
    "PEP",   # PepsiCo
    "COST",  # Costco
    "ADBE",  # Adobe
    "NFLX",  # Netflix
    "PYPL",  # PayPal
    "INTC",  # Intel
    "CSCO",  # Cisco
    "CMCSA", # Comcast
    "AMGN",  # Amgen
    "TXN",   # Texas Instruments
    "QCOM",  # Qualcomm
    "HON",   # Honeywell
    "AMD",   # Advanced Micro Devices (AMD)
    "ISRG",  # Intuitive Surgical
    "SBUX",  # Starbucks
    "MDLZ",  # Mondelēz
    "AMAT",  # Applied Materials
    "LRCX",  # Lam Research
    "ADI",   # Analog Devices
    "MU",    # Micron Technology
    "ASML", # ASML Holding
    "MRNA", # Moderna
    "ILMN",  # Illumina
    "BKNG",  # Booking Holdings
    "REGN",  # Regeneron
    "KDP",   # Keurig Dr Pepper
    "MNST",  # Monster Beverage
    "FISV",  # Fiserv
    "WDAY",  # Workday
    "TEAM"   # Atlassian
]

nyse_tickers = nyse_top_40 = [
    "XOM",   # Exxon Mobil
    "JNJ",   # Johnson & Johnson
    "V",     # Visa
    "PG",    # Procter & Gamble
    "MA",    # Mastercard
    "HD",    # Home Depot
    "DIS",   # Disney
    "VZ",    # Verizon
    "MCD",   # McDonald's
    "CVX",   # Chevron
    "WMT",   # Walmart
    "BAC",   # Bank of America
    "PFE",   # Pfizer
    "KO",    # Coca-Cola
    "MRK",   # Merck
    "ABBV",  # AbbVie
    "CRM",   # Salesforce
    "ABT",   # Abbott Laboratories
    "PEP",   # PepsiCo
    "C",     # Citigroup
    "TMO",   # Thermo Fisher Scientific
    "LIN",   # Linde
    "CSCO",  # Cisco (aussi coté sur NYSE)
    "ACN",   # Accenture
    "CVS",   # CVS Health
    "ORCL",  # Oracle
    "NKE",   # Nike
    "LLY",   # Eli Lilly
    "DHR",   # Danaher
    "UNH",   # UnitedHealth
    "PM",    # Philip Morris
    "IBM",   # IBM
    "MMM",   # 3M
    "MDT",   # Medtronic
    "GE",    # General Electric
    "GS",    # Goldman Sachs
    "CAT",   # Caterpillar
    "RTX",   # Raytheon Technologies
    "UPS",   # UPS
    "MO",    # Altria
]

# Inclure également les indices macro (VIX, Dollar Index, Brent, Or)
macro_tickers = [
    "GC=F",        # Or (Gold Futures COMEX)
    "BZ=F",        # Pétrole Brent (Brent Crude Oil Futures)
    "^NDX",        # NASDAQ 100 (technologie US, croissance)
    "^DJI",        # Dow Jones Industrial Average (blue chips US)
    "^SP500-20",   # S&P 500 Industrials (secteur industriel)
    "^SP500-15",   # S&P 500 Materials (matières premières)
    "^STOXX50E",   # Euro STOXX 50 (grandes capitalisations zone euro)
    "DX-Y.NYB",    # Dollar Index (DXY – force du dollar US)
    "EUR=X",       # Taux de change EUR/USD
    "CHF=X",       # Taux de change USD/CHF (valeur refuge)
    "^VIX",        # Indice de volatilité (peur / stress de marché)
    "^IRX",        # Taux US 13 semaines (T-Bills court terme)
    "^FVX",        # Taux US 5 ans
    "^TNX",        # Taux US 10 ans (benchmark macro mondial)
    "^TYX",        # Taux US 30 ans (long terme)
    "^CIISCSEP",   # Indice de surprises économiques Citi (US)
    "CDX"          # Indice de crédit (Credit Default Swaps – stress crédit)
]


# Combiner toutes les listes de tickers
all_tickers = cac40_tickers + nasdaq_tickers + nyse_tickers + macro_tickers

# Télécharger les données boursières
data = yf.download(all_tickers, start=start_date, end=end_date,auto_adjust=True)

# Calculer la variation en pourcentage par rapport à la clôture précédente
variation = data["Close"].pct_change(fill_method=None) * 100
variation = variation.dropna(how="all")

variation.index = pd.to_datetime(variation.index)
variation.index.name = "date"

dataset_ts = variation.reset_index()
dataset_ts = dataset_ts.sort_values("date")

print("Shape:", dataset_ts.shape)
print(dataset_ts.head())
print(dataset_ts.tail())
print("NaN par colonne :")
print(variation.isna().sum().sort_values(ascending=False).head(15))


dataset_ts.to_csv("DATASET_1000DAYS_VARIATION.csv", index=False)

now = datetime.now()
print(now)
# Out:
# [*********************100%***********************]  131 of 131 completed
# Shape: (710, 132)
# Ticker       date      AAPL      ABBV       ABT    ACA.PA       ACN      ADBE  \
# 0      2023-04-24  0.187858  1.028264 -1.128424  0.826757  0.332926 -0.087382
# 1      2023-04-25 -0.943563  0.499761 -0.389502 -1.494163 -2.362476 -2.053851
# 2      2023-04-26 -0.006138 -1.879931 -1.109384  0.980385  0.188396 -1.766822
# 3      2023-04-27  2.839544 -7.991354  0.689651  1.263966  1.563375  2.302654
# 4      2023-04-28  0.754103  1.511392  0.885837  0.253248  1.757113  1.653111
#
# Ticker       ADI     AI.PA    AIR.PA  ...      ^DJI      ^FVX      ^IRX  \
# 0       0.332731  0.233259  0.722597  ...  0.196509 -1.529637 -1.555549
# 1      -3.112964  0.000000 -0.427086  ... -1.017170 -4.521501  1.641698
# 2      -0.264988 -1.531105 -1.445588  ... -0.682825  1.104012  0.646074
# 3      -1.682724  0.995136  1.176655  ...  1.574353  3.505747  0.300900
# 4       1.272373  0.492687  1.274492  ...  0.804111 -1.832315 -1.540003
#
# Ticker      ^NDX  ^SP500-15  ^SP500-20  ^STOXX50E      ^TNX      ^TYX  \
# 0      -0.238523   0.692849   0.226674  -0.154018 -1.540611 -1.323457
# 1      -1.886306  -2.148293  -1.835074  -0.544089 -3.385496 -2.065448
# 2       0.639445  -1.178632  -1.869386  -0.688469  1.060071  1.040807
# 3       2.760710   1.358454   1.985282   0.237823  2.797209  1.816214
# 4       0.653190   1.128840   0.923219   0.028918 -2.154201 -2.076679
#
# Ticker       ^VIX
# 0        0.715557
# 1       11.071645
# 2        0.426439
# 3       -9.607216
# 4       -7.339994
#
# [5 rows x 132 columns]
# Ticker       date      AAPL      ABBV       ABT    ACA.PA       ACN      ADBE  \
# 705    2026-01-09  0.127388 -1.806988 -0.206057  0.654523 -0.408060 -1.501297
# 706    2026-01-12  0.339286 -0.018179 -1.016517 -0.254453  0.103316 -1.886515
# 707    2026-01-13  0.307392  0.322672 -0.272783  0.708617 -1.480639 -5.408210
# 708    2026-01-14 -0.417543  0.516421  0.563151 -0.534756  4.241337 -1.771365
# 709    2026-01-15  0.080790 -2.343502 -1.184003       NaN  0.010397 -0.149460
#
# Ticker       ADI     AI.PA    AIR.PA  ...      ^DJI      ^FVX      ^IRX  \
# 705     0.591653  1.977910 -0.046464  ...  0.483011  0.562096  0.171088
# 706    -2.349386  0.012597  0.488139  ...  0.173983  0.266170  0.569313
# 707     0.799703 -0.541494  1.873700  ... -0.803003 -0.637110  0.764222
# 708     0.600925  2.279052 -2.157130  ... -0.086110 -0.694631  0.000000
# 709     1.441328       NaN       NaN  ...  0.639477  0.887813  0.084277
#
# Ticker      ^NDX  ^SP500-15  ^SP500-20  ^STOXX50E      ^TNX      ^TYX  \
# 705     1.016031   1.803500   1.111870   1.577665 -0.286877 -0.802800
# 706     0.083056   0.736100   0.753278   0.313959  0.383596  0.435783
# 707    -0.177259   0.292286   0.513865   0.224894 -0.382130 -0.247936
# 708    -1.072218  -0.176485   0.139687  -0.410961 -0.743230 -0.683513
# 709     0.906918   0.640674   0.886597        NaN  0.338174 -0.208555
#
# Ticker      ^VIX
# 705    -6.213593
# 706     4.347827
# 707     5.687828
# 708     4.818526
# 709    -6.805972
#
# [5 rows x 132 columns]
# NaN par colonne :
# Ticker
# ^CIISCSEP    710
# FISV          50
# ^STOXX50E     49
# ABT           48
# ABBV          48
# AAPL          48
# ACN           48
# ASML          48
# AMZN          48
# ADI           48
# ADBE          48
# AVGO          48
# BAC           48
# BKNG          48
# CSCO          48
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Charger le CSV
dataset_ts = pd.read_csv(
    "DATASET_1000DAYS_VARIATION.csv",
    parse_dates=["date"]   # très important
)

# Trier par date (sécurité)
dataset_ts = dataset_ts.sort_values("date")

# Optionnel : remettre la date en index
dataset_ts = dataset_ts.set_index("date")

def scan_lead_lag_cac40(
    df,
    cac40_cols,
    other_cols,
    max_lag=20,
    min_obs=40,
    method="pearson"
):
    """
    Scan exhaustif lead/lag entre :
    - other_cols (X candidates)
    - cac40_cols (Y targets)

    Returns
    -------
    pd.DataFrame
    """

    results = []

    for y in cac40_cols:
        for x in other_cols:

            if x == y:
                continue

            best_row = None

            for lag in range(-max_lag, max_lag + 1):

                if lag < 0:
                    x_shifted = df[x].shift(-lag)
                    y_shifted = df[y]
                else:
                    x_shifted = df[x]
                    y_shifted = df[y].shift(lag)

                pair = pd.concat([x_shifted, y_shifted], axis=1).dropna()

                if len(pair) < min_obs:
                    continue

                corr = pair.iloc[:, 0].corr(pair.iloc[:, 1], method=method)

                if pd.isna(corr):
                    continue

                row = {
                    "x": x,
                    "y": y,
                    "lag": lag,
                    "correlation": corr,
                    "abs_corr": abs(corr),
                    "direction": "inverse" if corr < 0 else "same",
                    "n_obs": len(pair)
                }

                if best_row is None or row["abs_corr"] > best_row["abs_corr"]:
                    best_row = row

            if best_row is not None:
                results.append(best_row)

    return pd.DataFrame(results)


df = dataset_ts

cac40_cols = [
    "AI.PA","AIR.PA","ALO.PA","CS.PA","BNP.PA","EN.PA","CAP.PA","CA.PA",
    "ACA.PA","BN.PA","DSY.PA","EDEN.PA","ENGI.PA","EL.PA","ERF.PA","RMS.PA",
    "KER.PA","LR.PA","OR.PA","MC.PA","ML.PA","ORA.PA","RI.PA","PUB.PA",
    "RNO.PA","SAF.PA","SGO.PA","SAN.PA","SU.PA","GLE.PA","TEP.PA","HO.PA",
    "TTE.PA","URW.PA","VIE.PA","DG.PA","VIV.PA","WLN.PA"
]

other_cols = [c for c in df.columns if c not in cac40_cols]

results = scan_lead_lag_cac40(
    df=df,
    cac40_cols=cac40_cols,
    other_cols=other_cols,
    max_lag=20,
    min_obs=40
)

results.sort_values("abs_corr", ascending=False).head(20)
results[
    results["direction"] == "inverse"
].sort_values("abs_corr", ascending=False).head(20)

results[results["y"] == "MC.PA"] \
    .sort_values("abs_corr", ascending=False) \
    .head(10)

print("Shape:", results.shape)
print(results.head())
print(results.tail())

results.to_csv("LEAD_LAG_SCAN_CAC40.csv", index=False)

from datetime import datetime

now = datetime.now()
print(now)
# Out:
# Shape: (3496, 7)
#       x      y  lag  correlation  abs_corr direction  n_obs
# 0  AAPL  AI.PA   -1     0.160958  0.160958      same    646
# 1  ABBV  AI.PA   -1     0.179382  0.179382      same    646
# 2   ABT  AI.PA   -1     0.126668  0.126668      same    646
# 3   ACN  AI.PA   -1     0.192684  0.192684      same    646
# 4  ADBE  AI.PA    0     0.099059  0.099059      same    648
#               x       y  lag  correlation  abs_corr direction  n_obs
# 3491  ^SP500-20  WLN.PA    0     0.129506  0.129506      same    648
# 3492  ^STOXX50E  WLN.PA    0     0.264109  0.264109      same    661
# 3493       ^TNX  WLN.PA   -4    -0.088615  0.088615   inverse    637
# 3494       ^TYX  WLN.PA   -4    -0.092538  0.092538   inverse    637
# 3495       ^VIX  WLN.PA    0    -0.117784  0.117784   inverse    648

# %%
import pandas as pd

# =========================
# 1. CHARGEMENT DU CSV
# =========================

leadlag = pd.read_csv("LEAD_LAG_SCAN_CAC40.csv")

print("Dataset initial :", leadlag.shape)

# =========================
# 2. FILTRE : LAG ≠ 0
# =========================

leadlag = leadlag[leadlag["lag"] != 0]

print("Après suppression lag = 0 :", leadlag.shape)

# =========================
# 3. CLASSIFICATION DU RISQUE
# =========================

def classify_risk(abs_corr, n_obs):
    if abs_corr >= 0.55 and n_obs >= 80:
        return "very_low_risk"
    elif abs_corr >= 0.45 and n_obs >= 60:
        return "low_risk"
    elif abs_corr >= 0.40 and n_obs >= 50:
        return "medium_risk"
    elif abs_corr >= 0.30 and n_obs >= 40:
        return "high_risk"
    else:
        return "very_high_risk"

leadlag["risk_level"] = leadlag.apply(
    lambda r: classify_risk(r["abs_corr"], r["n_obs"]),
    axis=1
)

# =========================
# 4. TRI FINAL (DU + SÛR AU + RISQUÉ)
# =========================

risk_order = [
    "very_low_risk",
    "low_risk",
    "medium_risk",
    "high_risk",
    "very_high_risk"
]

leadlag["risk_level"] = pd.Categorical(
    leadlag["risk_level"],
    categories=risk_order,
    ordered=True
)

leadlag_sorted = leadlag.sort_values(
    ["risk_level", "abs_corr"],
    ascending=[True, False]
)

# =========================
# 5. CONTRÔLE RAPIDE
# =========================

print("\nTop 20 relations les plus sûres (lag ≠ 0) :")
print(leadlag_sorted.head(20))

# =========================
# 6. SAUVEGARDE
# =========================

leadlag_sorted.to_csv(
    "LEAD_LAG_SCAN_CAC40_CLASSIFIED_LAG_NOT_ZERO.csv",
    index=False
)

print("\nCSV sauvegardé : LEAD_LAG_SCAN_CAC40_CLASSIFIED_LAG_NOT_ZERO.csv")

# Charger le scan lead/lag
leadlag = pd.read_csv("LEAD_LAG_SCAN_CAC40.csv")

# Filtre SAFE
filtered = leadlag[
    (leadlag["lag"] != 0) &
    (leadlag["abs_corr"] >= 0.25) &
    (leadlag["n_obs"] >= 40)
]

# Extraire les candidats (variables X)
candidatesX = (
    filtered["x"]
    .value_counts()
    .reset_index()
)

candidatesX.columns = ["variable", "count"]
print("\nCandidate variables")
print(candidatesX)

# Extraire les cibles (variables y)
candidatesY = (
    filtered["y"]
    .value_counts()
    .reset_index()
)

candidatesY.columns = ["variable", "count"]
print("\nCandidate taget")
print(candidatesY)

from datetime import datetime

now = datetime.now()
print(now)
# Out:
# Dataset initial : (3496, 7)
# Après suppression lag = 0 : (2495, 7)
#
# Top 20 relations les plus sûres (lag ≠ 0) :
#               x        y  lag  correlation  abs_corr direction  n_obs  \
# 3403       ^VIX   VIV.PA    7    -0.307527  0.307527   inverse    634
# 3313       ABBV   VIV.PA  -20     0.287301  0.287301      same    626
# 1041       FISV  EDEN.PA    6    -0.267380  0.267380   inverse    634
# 319         LIN    CS.PA   -1     0.264982  0.264982      same    646
# 362   ^SP500-15    CS.PA   -1     0.264465  0.264465      same    646
# 2202  ^SP500-15   PUB.PA   -1     0.255874  0.255874      same    646
# 3118       ^DJI   URW.PA   -1     0.255748  0.255748      same    646
# 358        ^DJI    CS.PA   -1     0.255652  0.255652      same    646
# 3123  ^SP500-20   URW.PA   -1     0.253260  0.253260      same    646
# 3214  ^SP500-15   VIE.PA   -1     0.250224  0.250224      same    646
# 3210       ^DJI   VIE.PA   -1     0.249945  0.249945      same    646
# 2317        CDX   SAF.PA   -1     0.249407  0.249407      same    646
# 2203  ^SP500-20   PUB.PA   -1     0.246384  0.246384      same    646
# 3215  ^SP500-20   VIE.PA   -1     0.245803  0.245803      same    646
# 454   ^SP500-15   BNP.PA   -1     0.245713  0.245713      same    646
# 3127       ^VIX   URW.PA   -1    -0.243551  0.243551   inverse    646
# 363   ^SP500-20    CS.PA   -1     0.241657  0.241657      same    646
# 3122  ^SP500-15   URW.PA   -1     0.239094  0.239094      same    646
# 3323       AVGO   VIV.PA    4    -0.238918  0.238918   inverse    639
# 2198       ^DJI   PUB.PA   -1     0.236289  0.236289      same    646
#
#           risk_level
# 3403       high_risk
# 3313  very_high_risk
# 1041  very_high_risk
# 319   very_high_risk
# 362   very_high_risk
# 2202  very_high_risk
# 3118  very_high_risk
# 358   very_high_risk
# 3123  very_high_risk
# 3214  very_high_risk
# 3210  very_high_risk
# 2317  very_high_risk
# 2203  very_high_risk
# 3215  very_high_risk
# 454   very_high_risk
# 3127  very_high_risk
# 363   very_high_risk
# 3122  very_high_risk
# 3323  very_high_risk
# 2198  very_high_risk
#
# CSV sauvegardé : LEAD_LAG_SCAN_CAC40_CLASSIFIED_LAG_NOT_ZERO.csv
#
# Candidate variables
#     variable  count
# 0  ^SP500-15      3
# 1       ^DJI      2
# 2        LIN      1
# 3       FISV      1
# 4  ^SP500-20      1
# 5       ABBV      1
# 6       ^VIX      1
#
# Candidate taget
#   variable  count
# 0    CS.PA      3
# 1   URW.PA      2
# 2   VIV.PA      2
# 3  EDEN.PA      1
# 4   PUB.PA      1
# 5   VIE.PA      1
